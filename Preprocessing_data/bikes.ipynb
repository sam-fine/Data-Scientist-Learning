# %% [markdown]
# # Bike Data

# %%
import pandas as pd
import numpy as np

data = pd.read_csv(r'data/bikes_train.csv')

# %%
# review data
# missing values
# inconsistnet values (lower case, duplicates, datetime to to_datetime, not fitting patterns)
# plot features
# encode categroical data to make numerical (dummies)
# split to train and test
# normalise and scale if needed
# fit
# predict
#validate

# %%
data['datetime'] = pd.to_datetime(data['datetime'])
data.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
# plot
import matplotlib.pyplot as plt

plot_data = data.drop(['datetime', 'count'], axis=1)
fig, ax = plt.subplots(2,5, figsize=(15,8))
ax = ax.flatten()
for i, f in enumerate(plot_data.columns):
    ax[i].scatter(plot_data[f], data['count'])
    ax[i].set_xlabel(f)
    ax[i].set_ylabel('count')

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(plot_data)
y_train = data['count']
# Out:
# array([-1.34986372, -0.17149048, -1.46067232, -0.66017842, -2.49137234,
#        -2.70173625, -3.21585842, -1.56775367, -0.72104215, -1.02992795])

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()
